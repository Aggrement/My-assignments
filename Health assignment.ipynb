# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("healthexp.csv")

# %%
df.tail()
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
df.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             274 non-null    int64
#  1   Country          274 non-null    object
#  2   Spending_USD     274 non-null    float64
#  3   Life_Expectancy  274 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 269    False
# 270    False
# 271    False
# 272    False
# 273    False
# Length: 274, dtype: bool

# %%
df[df.duplicated()].shape
# Out:
# (0, 4)

# %%
df["Spending_USD"].hist()
# Out:
# <Axes: >

# %%
df["Life_Expectancy"].hist()
# Out:
# <Axes: >

# %%
plt.boxplot(df.Spending_USD)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2ae8e929ed0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2ae8e92b1d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2ae8e841890>],
#  'medians': [<matplotlib.lines.Line2D at 0x2ae8e93c290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2ae8e93c990>],
#  'means': []}

# %%
plt.boxplot(df.Life_Expectancy)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2ae8e9973d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2ae8e9a05d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2ae8b67b050>],
#  'medians': [<matplotlib.lines.Line2D at 0x2ae8e9a1790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2ae8e9a02d0>],
#  'means': []}

# %%
med=df["Spending_USD"].median()

# %%
print(med)
# Out:
# 2295.578

# %%
med=df["Life_Expectancy"].median()

# %%
print(med)
# Out:
# 78.1

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
sns.barplot(x='Country',y='Life_Expectancy',data=df)
plt.show()

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.barplot(x='Country',y='Spending_USD',data=df)
plt.show()
